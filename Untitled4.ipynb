# %% [markdown]
# # This is model Testing Code for DDPG in simulation

# %%
import tensorflow as tf     
import numpy as np          
import os
from game_environment import Data_Env
import pymysql

# %%
def save_test_data(step,score):
    step = str(step)
    score = str(score)
    db = pymysql.connect("localhost", "root", "root", "test")
    cursor = db.cursor()
    insert = "INSERT INTO test(step,score) VALUES('%s','%s')"%(step,score)
    result = cursor.execute(insert)
    db.close()
    print(insert)
    return result

# %%
def test(env, start, end, noise_sigma, init_memory, model_dir, experiment_dir,
                         actor, critic, memory,
                         actor_lr, critic_lr, batch_size,
                         gamma, tau=0.01):
    
    #build agent: action_range=(-1., 1.),reward_scale=1.
    agent = DDPG(actor, critic, memory, env.observation_shape, env.action_shape,
                 actor_lr=actor_lr, critic_lr=critic_lr, batch_size=batch_size,
                 gamma=gamma, tau=tau)
    saver = tf.train.Saver(max_to_keep=20)
    #------add save dir--------
    checkpoint_dir = os.path.join(experiment_dir, "checkpoints")
    checkpoint_path = os.path.join(checkpoint_dir, "model")
    if not os.path.exists(checkpoint_dir):
        os.makedirs(checkpoint_dir)
    #summary dir------------------
    summary_dir = os.path.join(experiment_dir, "summaries")
    if not os.path.exists(summary_dir):
        os.makedirs(summary_dir)
    summary_writer = tf.summary.FileWriter(summary_dir)
    summary = tf.Summary()
    episode_summary = tf.Summary()
    with tf.Session() as sess:
        latest_checkpoint = model_dir
        if latest_checkpoint:
            print("Loading model checkpoint {}...\n".format(latest_checkpoint))
            saver.restore(sess, latest_checkpoint)
            agent.sess = sess
        else:
            print('Building new model...')
            agent.initialize(sess)
        print('Generating ',init_memory,' memory... Please reset game!')
        for i in range(init_memory):
            wechat_score = 0
            jump_step = 0
            obs0 = env.reset()
            while 1:
                #get action
                feed_dict = {agent.obs0: [obs0]}
                action = sess.run(agent.actor_tf, feed_dict=feed_dict)
                print("action:%f"%action)
                action = action.flatten()
                obs1, reward, done, score = env.step(action)
                print(score)
                jump_step += 1
                if done:
                    save_test_data(jump_step,wechat_score)
                    break
                else:
                    wechat_score = score
                    obs0 =obs1

# %%
from model import Actor, Critic
from memory import Memory
from ddpg import DDPG
import cv2
from game_environment import Jump_Env as wechat_env

# %%
actor_lr = 1e-4
critic_lr = 1e-3
tau = 0.01
nb_actions = 1
batch_size = 128
limit=int(5000)
noise_sigma = 0.1
gamma = 0
init_memory = 100
# episodes = 10000
model_dir = "./experiments_9_1/checkpoints/model11700"#None
start = 0
end = 2000
experiment_dir = os.path.abspath("./experiments_9_1/")
number_templet = [cv2.imread('templet/{}.jpg'.format(i)) for i in range(10)]
restart_templet = cv2.imread('templet/again.jpg')
env = wechat_env(number_templet=number_templet, restart_templet=restart_templet)

# %%
actor = Actor(nb_actions, layer_norm=True)
critic = Critic(layer_norm=True)
memory = Memory(limit, action_shape=env.action_shape, observation_shape=env.observation_shape)

# %%
test(env=env, start=start, end=end, noise_sigma=noise_sigma, init_memory=init_memory, model_dir=model_dir, experiment_dir=experiment_dir, actor=actor, critic=critic, memory=memory, 
              actor_lr=actor_lr, critic_lr=critic_lr, batch_size=batch_size, gamma=gamma, tau=tau)
# Out:
# Actor
# Critic
# Critic
# Actor
# Critic
# setting up target updates ...
# len 16 = 16
# { target_actor/Conv/weights:0 } <- { actor/Conv/weights:0 }
# { target_actor/Conv/biases:0 } <- { actor/Conv/biases:0 }
# { target_actor/Conv_1/weights:0 } <- { actor/Conv_1/weights:0 }
# { target_actor/Conv_1/biases:0 } <- { actor/Conv_1/biases:0 }
# { target_actor/Conv_2/weights:0 } <- { actor/Conv_2/weights:0 }
# { target_actor/Conv_2/biases:0 } <- { actor/Conv_2/biases:0 }
# { target_actor/dense/kernel:0 } <- { actor/dense/kernel:0 }
# { target_actor/dense/bias:0 } <- { actor/dense/bias:0 }
# { target_actor/LayerNorm/beta:0 } <- { actor/LayerNorm/beta:0 }
# { target_actor/LayerNorm/gamma:0 } <- { actor/LayerNorm/gamma:0 }
# { target_actor/dense_1/kernel:0 } <- { actor/dense_1/kernel:0 }
# { target_actor/dense_1/bias:0 } <- { actor/dense_1/bias:0 }
# { target_actor/LayerNorm_1/beta:0 } <- { actor/LayerNorm_1/beta:0 }
# { target_actor/LayerNorm_1/gamma:0 } <- { actor/LayerNorm_1/gamma:0 }
# { target_actor/dense_2/kernel:0 } <- { actor/dense_2/kernel:0 }
# { target_actor/dense_2/bias:0 } <- { actor/dense_2/bias:0 }
# setting up target updates ...
# len 16 = 16
# { target_critic/Conv/weights:0 } <- { critic/Conv/weights:0 }
# { target_critic/Conv/biases:0 } <- { critic/Conv/biases:0 }
# { target_critic/Conv_1/weights:0 } <- { critic/Conv_1/weights:0 }
# { target_critic/Conv_1/biases:0 } <- { critic/Conv_1/biases:0 }
# { target_critic/Conv_2/weights:0 } <- { critic/Conv_2/weights:0 }
# { target_critic/Conv_2/biases:0 } <- { critic/Conv_2/biases:0 }
# { target_critic/dense/kernel:0 } <- { critic/dense/kernel:0 }
# { target_critic/dense/bias:0 } <- { critic/dense/bias:0 }
# { target_critic/LayerNorm/beta:0 } <- { critic/LayerNorm/beta:0 }
# { target_critic/LayerNorm/gamma:0 } <- { critic/LayerNorm/gamma:0 }
# { target_critic/dense_1/kernel:0 } <- { critic/dense_1/kernel:0 }
# { target_critic/dense_1/bias:0 } <- { critic/dense_1/bias:0 }
# { target_critic/LayerNorm_1/beta:0 } <- { critic/LayerNorm_1/beta:0 }
# { target_critic/LayerNorm_1/gamma:0 } <- { critic/LayerNorm_1/gamma:0 }
# { target_critic/dense_2/kernel:0 } <- { critic/dense_2/kernel:0 }
# { target_critic/dense_2/bias:0 } <- { critic/dense_2/bias:0 }
# setting up actor optimizer
# WARNING:tensorflow:From C:\Users\Stephen_Bo\Desktop\FYP\Final_Code\ddpg.py:13: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Loading model checkpoint ./experiments_9_1/checkpoints/model11700...
#
# INFO:tensorflow:Restoring parameters from ./experiments_9_1/checkpoints/model11700
# Generating  100  memory... Please reset game!
# C:\Users\Stephen_Bo\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# action:-0.256941
# 645
# 1
# action:-0.335007
# 598
# 2
# action:-0.519102
# 488
# 4
# action:-0.025951
# 784
# 8
# action:0.104089
# 862
# 9
# action:-0.508083
# 495
# 11
# action:-0.234171
# 659
# 12
# action:-0.281956
# 630
# 14
# action:-0.077830
# 753
# 15
# action:-0.449055
# 530
# 26
# action:-0.426147
# 544
# 27
# action:-0.316719
# 609
# 28
# action:-0.141733
# 714
# None
# INSERT INTO test(step,score) VALUES('13','28')
# action:-0.140178
# 715
# 1
# action:-0.124566
# 725
# 2
# action:-0.740203
# 355
# 3
# action:-0.741933
# 354
# 4
# action:-0.279428
# 632
# 25
# action:-0.261508
# 643
# 26
# action:-0.388294
# 567
# 27
# action:-0.596180
# 442
# 29
# action:-0.367863
# 579
# 30
# action:-0.365330
# 580
# 32
# action:-0.948751
# 230
# 33
# action:-0.208914
# 674
# 34
# action:-0.252993
# 648
# 35
# action:-0.422368
# 546
# 36
# action:-0.300484
# 619
# 37
# action:0.133888
# 880
# 9
# action:-0.195994
# 682
# 40
# action:-0.589942
# 446
# 41
# action:-0.561007
# 463
# 4
# action:-0.538756
# 476
# 6
# action:-0.058273
# 765
# 64
# action:-0.010796
# 793
# 6
# action:-0.077828
# 753
# None
# INSERT INTO test(step,score) VALUES('23','6')
# action:-0.124896
# 725
# 0
# action:-0.046145
# 772
# 0
# action:-0.380460
# 571
# None
# INSERT INTO test(step,score) VALUES('3','0')
# action:-0.124896
# 725
# 1
# action:0.088568
# 853
# 0
# action:-0.540164
# 475
# 4
# action:-0.315308
# 610
# 0
# action:-0.368851
# 578
# 6
# action:-0.908022
# 255
# 0
# action:-0.316350
# 610
# 4
# action:-0.024887
# 785
# 4
# action:-0.433777
# 539
# 44
# action:-0.345696
# 592
# 4
# action:-0.664176
# 401
# 46
# action:-0.086817
# 747
# 47
# action:-0.558893
# 464
# 4
# action:-0.208090
# 675
# 49
# action:-0.350381
# 589
# None
# INSERT INTO test(step,score) VALUES('15','49')
# action:-0.253612
# 647
# 1
# action:-0.624495
# 425
# 0
# action:-0.531902
# 480
# 0
# action:-0.106721
# 735
# 4
# action:-0.619468
# 428
# 0
# action:-0.073464
# 755
# None
# INSERT INTO test(step,score) VALUES('6','0')
# action:-0.167087
# 699
# 1
# action:-0.378097
# 573
# 0
# action:-0.394001
# 563
# 0
# action:-0.394001
# 563
# 0
# action:-0.574036
# 455
# 4
# action:-0.379402
# 572
# 0
# action:-0.519637
# 488
# None
# INSERT INTO test(step,score) VALUES('7','0')
# action:-0.188628
# 686
# 1
# action:-0.507045
# 495
# 0
# action:-0.365320
# 580
# 0
# action:-0.239599
# 656
# 4
# action:-0.006533
# 796
# 6
# action:-0.320496
# 607
# 7
# action:-0.453692
# 527
# 0
# action:-0.625466
# 424
# 9
# action:-0.449887
# 530
# 10
# action:-0.184215
# 689
# 1
# action:-0.414566
# 551
# 11
# action:-0.237124
# 657
# None
# INSERT INTO test(step,score) VALUES('12','11')
# action:-0.159292
# 704
# 0
# action:-0.242136
# 654
# 0
# action:-0.512201
# 492
# 4
# action:-0.183204
# 690
# 0
# action:-0.219505
# 668
# 6
# action:-0.082817
# 750
# None
# INSERT INTO test(step,score) VALUES('6','6')
# action:-0.253612
# 647
# 1
# action:-0.257354
# 645
# 0
# action:-0.176440
# 694
# 0
# action:-0.115076
# 730
# 4
# action:-0.532587
# 480
# 0
# action:-0.361633
# 583
# 6
# action:-0.428400
# 542
# 0
# action:0.025309
# 815
# 9
# action:-0.068855
# 758
# 10
# action:-0.484696
# 509
# 41
# action:-0.078949
# 752
# 4
# action:-0.009079
# 794
# None
# INSERT INTO test(step,score) VALUES('12','4')
# action:-0.253612
# 647
# 1
# action:-0.063722
# 761
# None
# INSERT INTO test(step,score) VALUES('2','1')
# action:-0.253612
# 647
# 1
# action:-0.431759
# 540
# 0
# action:-0.396058
# 562
# 4
# action:0.073113
# 843
# 0
# action:-0.457901
# 525
# 6
# action:-0.538264
# 477
# 11
# action:-0.321188
# 607
# None
# INSERT INTO test(step,score) VALUES('7','11')
# action:-0.124896
# 725
# 0
# action:-0.283858
# 629
# None
# INSERT INTO test(step,score) VALUES('2','0')
# action:-0.167087
# 699
# 0
# action:-0.395640
# 562
# 0
# action:-0.288236
# 627
# 4
# action:-0.227914
# 663
# 0
# action:-0.147265
# 711
# 6
# action:-0.064741
# 761
# 7
# action:-0.170202
# 697
# 0
# action:-0.334279
# 599
# 9
# action:0.077307
# 846
# None
# INSERT INTO test(step,score) VALUES('9','9')
# action:-0.169298
# 698
# 0
# action:0.150522
# 890
# 0
# action:-0.108322
# 735
# 4
# action:-0.034094
# 779
# 0
# action:-0.272181
# 636
# 7
# action:-0.627854
# 423
# 0
# action:-0.148795
# 710
# 9
# action:-0.447510
# 531
# None
# INSERT INTO test(step,score) VALUES('8','9')
# action:-0.124896
# 725
# 0
# action:-0.311608
# 613
# 1
# action:-0.413784
# 551
# None
# INSERT INTO test(step,score) VALUES('3','1')
# action:-0.169298
# 698
# 1
# action:-0.383986
# 569
# 0
# action:-0.210873
# 673
# 0
# action:-0.009889
# 794
# 4
# action:-0.393175
# 564
# 0
# action:-0.539269
# 476
# None
# INSERT INTO test(step,score) VALUES('6','0')
# action:-0.188628
# 686
# 1
# action:-0.490773
# 505
# 0
# action:-0.526848
# 483
# None
# INSERT INTO test(step,score) VALUES('3','0')
# action:-0.124896
# 725
# 0
# action:-0.105036
# 736
# 0
# action:-0.835545
# 298
# 4
# action:-0.361161
# 583
# 0
# action:-0.275000
# 635
# 6
# action:-0.243000
# 654
# None
# INSERT INTO test(step,score) VALUES('6','6')
# action:-0.169298
# 698
# 0
# action:-0.438356
# 536
# 0
# action:-0.026700
# 783
# 0
# action:-0.539349
# 476
# 6
# action:-0.360552
# 583
# 7
# action:-0.340815
# 595
# 0
# action:-0.303727
# 617
# 9
# action:-0.237128
# 657
# 10
# action:0.042853
# 825
# 11
# action:-0.296522
# 622
# 17
# action:-0.562886
# 462
# 19
# action:-0.669551
# 398
# 0
# action:-0.522222
# 486
# 1
# action:-0.307269
# 615
# 0
# action:-0.265772
# 640
# 24
# action:-0.337933
# 597
# 26
# action:-0.664389
# 401
# 27
# action:-0.483784
# 509
# None
# INSERT INTO test(step,score) VALUES('18','27')
# action:-0.263808
# 641
# 1
# action:-0.747223
# 351
# 2
# action:-0.149907
# 710
# None
# INSERT INTO test(step,score) VALUES('3','2')
# action:-0.263808
# 641
# 1
# action:-0.362281
# 582
# 2
# action:-0.105801
# 736
# 3
# action:-0.464442
# 521
# 5
# action:-0.817861
# 309
# None
# INSERT INTO test(step,score) VALUES('5','5')
# action:-0.187719
# 687
# 1
# action:-0.002116
# 798
# 2
# action:-0.582648
# 450
# 3
# action:-0.391318
# 565
# 4
# action:-0.076425
# 754
# 25
# action:-0.001338
# 799
# 26
# action:-0.189709
# 686
# None
# INSERT INTO test(step,score) VALUES('7','26')
# action:-0.201376
# 679
# 1
# action:-0.030798
# 781
# 2
# action:-0.529022
# 482
# 3
# action:-0.513032
# 492
# 4
# action:-0.112664
# 732
# 5
# action:0.011412
# 806
# None
# INSERT INTO test(step,score) VALUES('6','5')
# action:-0.201376
# 679
# 1
# action:-0.659430
# 404
# 3
# action:-0.206923
# 675
# 7
# action:-0.039621
# 776
# 8
# action:-0.542249
# 474
# 1
# action:-0.494045
# 503
# None
# INSERT INTO test(step,score) VALUES('6','1')
# action:-0.096806
# 741
# 1
# action:-0.489661
# 506
# 2
# action:-0.826247
# 304
# 3
# action:0.011919
# 807
# 4
# action:-0.154546
# 707
# 25
# action:-0.455234
# 526
# 26
# action:-0.000968
# 799
# 27
# action:-0.119012
# 728
# 28
# action:-0.425595
# 544
# 11
# action:-0.643020
# 414
# None
# INSERT INTO test(step,score) VALUES('10','11')
# action:-0.273711
# 635
# 1
# action:-0.729015
# 362
# 2
# action:-0.382516
# 570
# 3
# action:-0.199552
# 680
# 4
# action:-0.369601
# 578
# 26
# action:-0.641807
# 414
# 27
# action:-0.301798
# 618
# 28
# action:-0.404042
# 557
# 30
# action:-0.374951
# 575
# 34
# action:-0.133627
# 719
# 35
# action:-0.314168
# 611
# 36
# action:-0.050515
# 769
# 37
# action:-0.314459
# 611
# None
# INSERT INTO test(step,score) VALUES('13','37')
# action:-0.201376
# 679
# 1
# action:-0.520509
# 487
# 2
# action:-0.553197
# 468
# 3
# action:0.020733
# 812
# 4
# action:-0.183704
# 689
# 35
# action:-0.393902
# 563
# None
# INSERT INTO test(step,score) VALUES('6','35')
# action:-0.263808
# 641
# 1
# action:-0.090057
# 745
# 2
# action:-0.546354
# 472
# 3
# action:-0.202673
# 678
# 4
# action:-0.392197
# 564
# 5
# action:-0.438121
# 537
# 6
# action:-0.073006
# 756
# 8
# action:-0.534599
# 479
# 9
# action:-0.585268
# 448
# 11
# action:-0.299747
# 620
# 12
# action:-0.004476
# 797
# 13
# action:-0.639781
# 416
# 14
# action:0.139042
# 883
# 15
# action:-0.647779
# 411
# 16
# action:-0.324477
# 605
# 47
# action:-0.751019
# 349
# 48
# action:-0.191550
# 685
# None
# INSERT INTO test(step,score) VALUES('17','48')
# action:-0.180511
# 691
# 1
# action:-0.310782
# 613
# 0
# action:-0.378772
# 572
# 0
# action:-0.282825
# 630
# 0
# action:-0.689034
# 386
# 6
# action:-0.337730
# 597
# 7
# action:-0.137982
# 717
# 8
# action:-0.711180
# 373
# 9
# action:-0.476221
# 514
# 10
# action:0.012554
# 807
# 11
# action:-0.533947
# 479
# None
# INSERT INTO test(step,score) VALUES('11','11')
# action:-0.254784
# 647
# 1
# action:-0.111810
# 732
# 0
# action:-0.873279
# 276
# 0
# action:-0.087887
# 747
# 4
# action:-0.394698
# 563
# 0
# action:-0.336460
# 598
# None
# INSERT INTO test(step,score) VALUES('6','0')
# action:-0.244199
# 653
# 1
# action:-0.081081
# 751
# None
# INSERT INTO test(step,score) VALUES('2','1')
# action:-0.123504
# 725
# 0
# action:-0.350048
# 589
# 0
# action:-0.367674
# 579
# 4
# action:-0.550724
# 469
# 6
# action:-0.035523
# 778
# 7
# action:-0.311811
# 612
# 8
# action:-0.492557
# 504
# 9
# action:-0.127671
# 723
# None
# INSERT INTO test(step,score) VALUES('8','9')
# action:-0.244199
# 653
# 1
# action:-0.244144
# 653
# 0
# action:-0.177986
# 693
# 0
# action:-0.215568
# 670
# 1
# action:-0.390824
# 565
# None
# INSERT INTO test(step,score) VALUES('5','1')
# action:-0.180511
# 691
# 1
# action:-0.409013
# 554
# 0
# action:-0.409699
# 554
# 0
# action:-0.521334
# 487
# 0
# action:-0.409720
# 554
# 1
# action:-0.403638
# 557
# None
# INSERT INTO test(step,score) VALUES('6','1')
# action:-0.122429
# 726
# 0
# action:-0.396287
# 562
# 0
# action:-0.050056
# 769
# 4
# action:-0.320317
# 607
# None
# INSERT INTO test(step,score) VALUES('4','4')
# action:-0.123504
# 725
# 1
# action:-0.072279
# 756
# 0
# action:-0.312135
# 612
# 0
# action:-0.283903
# 629
# 4
# action:-0.118164
# 729
# None
# INSERT INTO test(step,score) VALUES('5','4')
# action:-0.161700
# 702
# 0
# action:-0.771510
# 337
# 0
# action:-0.206605
# 676
# 4
# action:-0.355637
# 586
# None
# INSERT INTO test(step,score) VALUES('4','4')
# action:-0.180511
# 691
# 1
# action:0.088805
# 853
# 0
# action:-0.644360
# 413
# 0
# action:-0.276473
# 634
# None
# INSERT INTO test(step,score) VALUES('4','0')
# action:-0.123504
# 725
# 0
# action:-0.250407
# 649
# 0
# action:-0.522870
# 486
# None
# INSERT INTO test(step,score) VALUES('3','0')
# action:-0.123504
# 725
# 0
# action:-0.318392
# 608
# 0
# action:-0.198277
# 681
# None
# INSERT INTO test(step,score) VALUES('3','0')
# action:-0.152982
# 708
# 0
# action:-0.117182
# 729
# 0
# action:-0.145835
# 712
# 4
# action:-0.046616
# 772
# 0
# action:-0.464615
# 521
# 1
# action:-0.527015
# 483
# None
# INSERT INTO test(step,score) VALUES('6','1')
# action:-0.254784
# 647
# 1
# action:-0.157410
# 705
# 0
# action:-0.001029
# 799
# 0
# action:-0.229646
# 662
# 1
# action:-0.365217
# 580
# None
# INSERT INTO test(step,score) VALUES('5','1')
# action:-0.161700
# 702
# 0
# action:-0.377564
# 573
# 0
# action:-0.161758
# 702
# 4
# action:-0.410675
# 553
# 0
# action:-0.233096
# 660
# 6
# action:0.086052
# 851
# 7
# action:-0.058912
# 764
# 8
# action:-0.032802
# 780
# 9
# action:-0.129845
# 722
# 10
# action:-0.178905
# 692
# 11
# action:-0.317276
# 609
# None
# INSERT INTO test(step,score) VALUES('11','11')
# action:-0.244199
# 653
# 1
# action:-0.245534
# 652
# 0
# action:-0.364656
# 581
# 0
# action:-0.518386
# 488
# 0
# action:0.083673
# 850
# 11
# action:-0.505993
# 496
# None
# INSERT INTO test(step,score) VALUES('6','11')
# action:-0.195330
# 682
# 1
# action:-0.741549
# 355
# 0
# action:-0.208999
# 674
# 0
# action:0.039328
# 823
# 4
# action:-0.242921
# 654
# 10
# action:-0.598498
# 440
# 11
# action:-0.454439
# 527
# 1
# action:-0.215641
# 670
# 1
# action:-0.113283
# 732
# 1
# action:0.017183
# 810
# 19
# action:-0.194261
# 683
# 0
# action:-0.512002
# 492
# 0
# action:-0.617735
# 429
# 0
# action:-0.038907
# 776
# 4
# action:-0.318413
# 608
# 35
# action:-0.210240
# 673
# 36
# action:-0.534480
# 479
# 37
# action:-0.104120
# 737
# None
# INSERT INTO test(step,score) VALUES('18','37')
# action:-0.130642
# 721
# 2
# action:-0.445180
# 532
# 3
# action:-0.443980
# 533
# 4
# action:-0.291739
# 624
# 5
# action:0.169033
# 901
# 6
# action:-0.293032
# 624
# 7
# action:-0.043998
# 773
# 8
# action:0.113548
# 868
# 10
# action:-0.088509
# 746
# 11
# action:-0.761255
# 343
# 12
# action:-0.575613
# 454
# 13
# action:-0.202199
# 678
# 14
# action:-0.588715
# 446
# 16
# action:-0.375124
# 574
# 17
# action:-0.567538
# 459
# 38
# action:-0.514031
# 491
# None
# INSERT INTO test(step,score) VALUES('16','38')
# action:-0.183050
# 690
# 1
# action:-0.179339
# 692
# 2
# action:-0.093515
# 743
# 3
# action:-0.643255
# 414
# 5
# action:-0.094840
# 743
# 9
# action:-0.480785
# 511
# 15
# action:-0.308083
# 615
# 16
# action:-0.053630
# 767
# 17
# action:-0.271771
# 636
# 18
# action:-0.481151
# 511
# 19
# action:-0.262342
# 642
# 20
# action:-0.418415
# 548
# 21
# action:-0.292077
# 624
# 23
# action:-0.454622
# 527
# 24
# action:0.012407
# 807
# 25
# action:-0.552144
# 468
# 26
# action:-0.293972
# 623
# 27
# action:0.022090
# 813
# 28
# action:-0.480402
# 511
# 29
# action:-0.137934
# 717
# 60
# action:-0.134380
# 719
# 61
# action:-0.083634
# 749
# 63
# action:0.020663
# 812
# 64
# action:-0.027071
# 783
# 65
# action:-0.189839
# 686
# 66
# action:-0.373477
# 575
# 67
# action:-0.306560
# 616
# 69
# action:-0.493852
# 503
# 70
# action:-0.346974
# 591
# 71
# action:-0.632936
# 420
# 93
# action:-0.311895
# 612
# 93
# action:-0.405365
# 556
# None
# INSERT INTO test(step,score) VALUES('32','93')
# action:-0.256941
# 645
# 1
# action:-0.445337
# 532
# 2
# action:-0.499704
# 500
# 3
# action:-0.269823
# 638
# 5
# action:-0.231713
# 660
# 36
# action:-0.733236
# 360
# 37
# action:-0.441502
# 535
# None
# INSERT INTO test(step,score) VALUES('7','37')
# action:-0.185680
# 688
# 1
# action:-0.428049
# 543
# 3
# action:-0.417864
# 549
# 4
# action:-0.164897
# 701
# 5
# action:-0.588373
# 446
# 6
# action:-0.463912
# 521
# 7
# action:-0.192397
# 684
# 8
# action:0.157622
# 894
# 9
# action:-0.435345
# 538
# 11
# action:-0.098874
# 740
# None
# INSERT INTO test(step,score) VALUES('10','11')
# action:-0.256941
# 645
# 1
# action:-0.364340
# 581
# 2
# action:-0.143486
# 713
# None
# INSERT INTO test(step,score) VALUES('3','2')
# action:-0.228517
# 662
# 1
# action:-0.424028
# 545
# 2
# action:-0.640107
# 415
# 3
# action:-0.815899
# 310
# 4
# action:-0.290474
# 625
# 5
# action:-0.376374
# 574
# 6
# action:-0.404214
# 557
# 7
# action:-0.192878
# 684
# 8
# action:-0.401315
# 559
# 9
# action:-0.365507
# 580
# 11
# action:-0.340657
# 595
# 15
# action:-0.503972
# 497
# 16
# action:-0.193286
# 684
# None
# INSERT INTO test(step,score) VALUES('13','16')
# action:-0.264801
# 641
# 1
# action:0.023789
# 814
# 2
# action:-0.699381
# 380
# None
# INSERT INTO test(step,score) VALUES('3','2')
# action:-0.228517
# 662
# 1
# action:-0.135511
# 718
# 2
# action:-0.441862
# 534
# 3
# action:-0.742035
# 354
# 4
# action:-0.434443
# 539
# 5
# action:-0.679691
# 392
# None
# INSERT INTO test(step,score) VALUES('6','5')
# action:-0.213485
# 671
# 1
# action:-0.542987
# 474
# 3
# action:-0.228037
# 663
# 4
# action:-0.715262
# 370
# 5
# action:0.077078
# 846
# 7
# action:-0.708345
# 374
# 11
# action:-0.376925
# 573
# 12
# action:0.097150
# 858
# None
# INSERT INTO test(step,score) VALUES('8','12')
# action:-0.185680
# 688
# 1
# action:-0.045029
# 772
# 2
# action:-0.200854
# 679
# 3
# action:-0.632443
# 420
# 5
# action:-0.278306
# 633
# 9
# action:-0.161989
# 702
# 10
# action:-0.032267
# 780
# 11
# action:-0.823329
# 306
# None
# INSERT INTO test(step,score) VALUES('8','11')
# action:-0.228517
# 662
# 1
# action:-0.123097
# 726
# 2
# action:-0.702009
# 378
# None
# INSERT INTO test(step,score) VALUES('3','2')
# action:-0.185680
# 688
# 1
# action:-0.210312
# 673
# 2
# action:-0.263971
# 641
# 4
# action:-0.270105
# 637
# 5
# action:-0.461073
# 523
# None
# INSERT INTO test(step,score) VALUES('5','5')
# action:-0.228517
# 662
# 1
# action:-0.168425
# 698
# 2
# action:-0.425605
# 544
# 3
# action:-0.489879
# 506
# 5
# action:-0.043155
# 774
# 16
# action:0.031418
# 818
# 17
# action:-0.405286
# 556
# 18
# action:-0.236341
# 658
# 19
# action:-0.417738
# 549
# 20
# action:0.043955
# 826
# 41
# action:-0.804470
# 317
# None
# INSERT INTO test(step,score) VALUES('11','41')
# action:-0.185680
# 688
# 1
# action:-0.456806
# 525
# 2
# action:-0.560248
# 463
# 3
# action:-0.322544
# 606
# 4
# action:-0.257700
# 645
# 5
# action:-0.254272
# 647
# 6
# action:-0.027685
# 783
# 7
# action:-0.419033
# 548
# 9
# action:-0.413419
# 551
# 10
# action:-0.026904
# 783
# 11
# action:-0.506730
# 495
# None
# INSERT INTO test(step,score) VALUES('11','11')
# action:-0.140178
# 715
# 2
# action:-0.008357
# 794
# 3
# action:-0.741885
# 354
# 4
# action:-0.878314
# 273
# 5
# action:-0.332904
# 600
# 6
# action:-0.080459
# 751
# 7
# action:-0.136672
# 717
# 8
# action:-0.096988
# 741
# 1
# action:-0.476640
# 514
# None
# INSERT INTO test(step,score) VALUES('9','1')
# action:-0.173578
# 695
# 1
# action:0.008208
# 804
# 2
# action:-0.681415
# 391
# 3
# action:-0.190084
# 685
# None
# INSERT INTO test(step,score) VALUES('4','3')
# action:-0.185680
# 688
# 1
# action:0.123319
# 873
# 2
# action:-0.071220
# 757
# 3
# action:-0.326222
# 604
# 4
# action:-0.123165
# 726
# 15
# action:-0.750275
# 349
# 16
# action:-0.476350
# 514
# 17
# action:-0.377555
# 573
# 18
# action:-0.209210
# 674
# None
# INSERT INTO test(step,score) VALUES('9','18')
# action:-0.204308
# 677
# 1
# action:-0.168489
# 698
# 2
# action:-0.271439
# 637
# 3
# action:-0.142094
# 714
# 4
# action:-0.494760
# 503
# 5
# action:-0.007420
# 795
# 6
# action:-0.414819
# 551
# 8
# action:-0.411984
# 552
# 9
# action:0.131981
# 879
# 10
# action:-0.350407
# 589
# 11
# action:-0.375898
# 574
# 12
# action:-0.081610
# 751
# 13
# action:-0.670888
# 397
# 14
# action:-0.205020
# 676
# 15
# action:-0.088070
# 747
# None
# INSERT INTO test(step,score) VALUES('15','15')
# action:-0.256941
# 645
# 1
# action:-0.239506
# 656
# 2
# action:-0.474814
# 515
# 3
# action:-0.218833
# 668
# 5
# action:-0.046324
# 772
# 6
# action:-0.589187
# 446
# 7
# action:-0.567718
# 459
# 8
# action:-0.281093
# 631
# 9
# action:-0.020711
# 787
# 10
# action:-0.335558
# 598
# 41
# action:-0.694500
# 383
# 42
# action:-0.308718
# 614
# 43
# action:-0.348341
# 590
# 44
# action:0.081230
# 848
# 45
# action:-0.532126
# 480
# 46
# action:-0.345742
# 592
# 47
# action:-0.668174
# 399
# 4
# action:-0.455246
# 526
# 49
# action:-0.497903
# 501
# 0
# action:-0.352583
# 588
# 1
# action:-0.058679
# 764
# 0
# action:-0.285472
# 628
# 0
# action:-0.337894
# 597
# None
# INSERT INTO test(step,score) VALUES('23','0')
# action:-0.169298
# 698
# 0
# action:-0.052498
# 768
# 6
# action:-0.362142
# 582
# 7
# action:-0.072273
# 756
# None
# INSERT INTO test(step,score) VALUES('4','7')
# action:-0.174513
# 695
# 0
# action:-0.158479
# 704
# 0
# action:-0.020637
# 787
# 4
# action:-0.305190
# 616
# 6
# action:-0.153904
# 707
# 7
# action:-0.392525
# 564
# None
# INSERT INTO test(step,score) VALUES('6','7')
# action:-0.188628
# 686
# 1
# action:-0.742793
# 354
# 0
# action:-0.167105
# 699
# None
# INSERT INTO test(step,score) VALUES('3','0')
# action:-0.169298
# 698
# 1
# action:-0.452504
# 528
# 0
# action:-0.091774
# 744
# 1
# action:-0.317567
# 609
# None
# INSERT INTO test(step,score) VALUES('4','1')
# action:-0.253612
# 647
# 1
# action:-0.709738
# 374
# 0
# action:-0.365694
# 580
# 0
# action:-0.385534
# 568
# 4
# action:-0.564285
# 461
# 0
# action:-0.415023
# 550
# 6
# action:-0.495512
# 502
# None
# INSERT INTO test(step,score) VALUES('7','6')
# action:-0.188628
# 686
# 1
# action:-0.212768
# 672
# 0
# action:-0.256236
# 646
# 0
# action:-0.154204
# 707
# 0
# action:-0.197422
# 681
# 6
# action:-0.323866
# 605
# 7
# action:-0.233087
# 660
# None
# INSERT INTO test(step,score) VALUES('7','7')
# action:-0.159292
# 704
# 0
# action:-0.264938
# 641
# 0
# action:-0.781607
# 331
# 4
# action:-0.375303
# 574
# 0
# action:-0.324061
# 605
# 6
# action:-0.354766
# 587
# None
# INSERT INTO test(step,score) VALUES('6','6')
# action:-0.124896
# 725
# 0
# action:-0.765351
# 340
# 0
# action:-0.246875
# 651
# 4
# action:-0.558642
# 464
# 6
# action:-0.590592
# 445
# 17
# action:-0.538950
# 476
# 1
# action:0.102940
# 861
# 19
# action:-0.383288
# 570
# 0
# action:-0.254189
# 647
# 1
# action:-0.310554
# 613
# 0
# action:-0.370139
# 577
# 4
# action:-0.053752
# 767
# 0
# action:-0.315214
# 610
# None
# INSERT INTO test(step,score) VALUES('13','0')
# action:-0.169298
# 698
# 0
# action:-0.388183
# 567
# 0
# action:-0.056573
# 766
# 4
# action:-0.385452
# 568
# 6
# action:-0.307151
# 615
# None
# INSERT INTO test(step,score) VALUES('5','6')
# action:-0.169298
# 698
# 1
# action:-0.144815
# 713
# None
# INSERT INTO test(step,score) VALUES('2','1')
# action:-0.159292
# 704
# 0
# action:-0.304587
# 617
# 0
# action:-0.055133
# 766
# 4
# action:-0.204896
# 677
# 0
# action:-0.025583
# 784
# None
# INSERT INTO test(step,score) VALUES('5','0')
# action:-0.127680
# 723
# 1
# action:-0.251192
# 649
# 0
# action:-0.469756
# 518
# 1
# action:-0.348866
# 590
# None
# INSERT INTO test(step,score) VALUES('4','1')
# action:-0.127680
# 723
# 0
# action:-0.294865
# 623
# 0
# action:-0.168871
# 698
# None
# INSERT INTO test(step,score) VALUES('3','0')
# action:-0.253612
# 647
# 1
# action:-0.019465
# 788
# None
# INSERT INTO test(step,score) VALUES('2','1')
# action:-0.124896
# 725
# 0
# action:-0.481972
# 510
# 6
# action:-0.491531
# 505
# 7
# action:-0.683255
# 390
# 9
# action:-0.183000
# 690
# 1
# action:-0.428770
# 542
# None
# INSERT INTO test(step,score) VALUES('6','1')
# action:-0.127680
# 723
# 0
# action:-0.034572
# 779
# 0
# action:-0.436026
# 538
# 4
# action:-0.216721
# 669
# 0
# action:-0.103749
# 737
# None
# INSERT INTO test(step,score) VALUES('5','0')
# action:-0.169298
# 698
# 1
# action:-0.312589
# 612
# 0
# action:-0.475981
# 514
# 1
# action:-0.461687
# 522
# None
# INSERT INTO test(step,score) VALUES('4','1')
# action:-0.167087
# 699
# 1
# action:-0.186628
# 688
# None
# INSERT INTO test(step,score) VALUES('2','1')
# action:-0.169298
# 698
# 1
# action:-0.413311
# 552
# 0
# action:-0.083080
# 750
# 4
# action:-0.314972
# 611
# 0
# action:-0.079948
# 752
# 11
# action:-0.267487
# 639
# 1
# action:-0.353197
# 588
# 1
# action:-0.479606
# 512
# 14
# action:-0.410738
# 553
# None
# INSERT INTO test(step,score) VALUES('9','14')
# action:-0.253612
# 647
# 1
# action:-0.574082
# 455
# 0
# action:-0.099968
# 740
# 0
# action:-0.165480
# 700
# None
# INSERT INTO test(step,score) VALUES('4','0')
# action:-0.159292
# 704
# 1
# action:-0.399659
# 560
# 0
# action:-0.433559
# 539
# 0
# action:-0.663934
# 401
# 4
# action:-0.471173
# 517
# None
# INSERT INTO test(step,score) VALUES('5','4')
# action:-0.127680
# 723
# 0
# action:-0.450136
# 529
# None
# INSERT INTO test(step,score) VALUES('2','0')
# action:-0.188628
# 686
# 1
# action:-0.326383
# 604
# 0
# action:-0.347176
# 591
# 0
# action:-0.741212
# 355
# 4
# action:-0.203166
# 678
# 0
# action:-0.294594
# 623
# 7
# action:-0.252386
# 648
# 0
# action:-0.547777
# 471
# 9
# action:-0.435634
# 538
# 10
# action:-0.380961
# 571
# 11
# action:-0.062219
# 762
# 1
# action:-0.446357
# 532
# 1
# action:0.054129
# 832
# 14
# action:-0.388888
# 566
# None
# INSERT INTO test(step,score) VALUES('14','14')
# action:-0.241307
# 655
# 1
# action:-0.605438
# 436
# 0
# action:-0.231177
# 661
# 0
# action:-0.438942
# 536
# 4
# action:-0.736915
# 357
# None
# INSERT INTO test(step,score) VALUES('5','4')
# action:-0.174513
# 695
# 1
# action:-0.147661
# 711
# 0
# action:-0.074835
# 755
# 0
# action:-0.214472
# 671
# None
# INSERT INTO test(step,score) VALUES('4','0')
# action:-0.169298
# 698
# 0
# action:-0.361678
# 582
# 0
# action:0.015359
# 809
# 0
# action:-0.022208
# 786
# 6
# action:-0.911121
# 253
# 7
# action:-0.693212
# 384
# None
# INSERT INTO test(step,score) VALUES('6','7')
# action:-0.188628
# 686
# 1
# action:0.114863
# 868
# 0
# action:-0.405821
# 556
# 0
# action:-0.837442
# 297
# 4
# action:-0.168327
# 699
# 0
# action:-0.036532
# 778
# 6
# action:-0.510136
# 493
# 7
# action:-0.082665
# 750
# 0
# action:-0.271986
# 636
# 9
# action:-0.742828
# 354
# 0
# action:-0.233138
# 660
# 11
# action:-0.473979
# 515
# None
# INSERT INTO test(step,score) VALUES('12','11')
# action:-0.174513
# 695
# 1
# action:-0.315791
# 610
# 0
# action:-0.279969
# 632
# 0
# action:-0.051500
# 769
# None
# INSERT INTO test(step,score) VALUES('4','0')
# action:-0.169298
# 698
# 0
# action:-0.425127
# 544
# 0
# action:-0.724173
# 365
# 4
# action:-0.483826
# 509
# 6
# action:-0.270506
# 637
# 1
# action:-0.377462
# 573
# 1
# action:-0.475680
# 514
# 14
# action:-0.859332
# 284
# 1
# action:-0.400341
# 559
# 16
# action:-0.129429
# 722
# 17
# action:-0.470945
# 517
# 1
# action:0.068686
# 841
# 19
# action:-0.522117
# 486
# 0
# action:-0.350458
# 589
# None
# INSERT INTO test(step,score) VALUES('14','0')
# action:-0.253612
# 647
# 1
# action:-0.332307
# 600
# 0
# action:-0.018127
# 789
# 0
# action:-0.170372
# 697
# 4
# action:-0.139062
# 716
# 0
# action:-0.237653
# 657
# 6
# action:-0.122226
# 726
# None
# INSERT INTO test(step,score) VALUES('7','6')
# action:-0.169298
# 698
# 1
# action:-0.505067
# 496
# 0
# action:-0.378387
# 572
# 4
# action:-0.499313
# 500
# 0
# action:-0.210210
# 673
# 7
# action:-0.308252
# 615
# 0
# action:-0.023602
# 785
# 9
# action:-0.169794
# 698
# 10
# action:-0.379224
# 572
# 11
# action:-0.344748
# 593
# 1
# action:-0.474830
# 515
# 1
# action:0.041100
# 824
# 1
# action:-0.389721
# 566
# 16
# action:-0.035626
# 778
# 17
# action:-0.161357
# 703
# 28
# action:-0.721932
# 366
# 29
# action:-0.441533
# 535
# 30
# action:-0.172427
# 696
# 11
# action:-0.432370
# 540
# None
# INSERT INTO test(step,score) VALUES('19','11')
# action:-0.167936
# 699
# 1
# action:-0.407805
# 555
# 2
# action:-0.111186
# 733
# 3
# action:-0.332783
# 600
# 5
# action:-0.563953
# 461
# 6
# action:-0.006633
# 796
# 7
# action:0.090668
# 854
# 9
# action:0.278801
# 967
# 10
# action:-0.293462
# 623
# 11
# action:-0.677553
# 393
# 13
# action:-0.128001
# 723
# 14
# action:-0.446604
# 532
# 16
# action:-0.386103
# 568
# 17
# action:0.075489
# 845
# 19
# action:-0.488885
# 506
# 20
# action:-0.276367
# 634
# None
# INSERT INTO test(step,score) VALUES('16','20')
# action:-0.180511
# 691
# 1
# action:-0.463012
# 522
# 0
# action:-0.436500
# 538
# 0
# action:-0.107378
# 735
# 4
# action:-0.230998
# 661
# None
# INSERT INTO test(step,score) VALUES('5','4')
# action:-0.254784
# 647
# 1
# action:-0.181968
# 690
# 0
# action:-0.023477
# 785
# 0
# action:0.107955
# 864
# 4
# action:-0.478715
# 512
# 0
# action:-0.203956
# 677
# 6
# action:-0.719888
# 368
# 7
# action:-0.256871
# 645
# 0
# action:-0.532331
# 480
# None
# INSERT INTO test(step,score) VALUES('9','0')
# action:-0.244199
# 653
# 1
# action:-0.071821
# 756
# 0
# action:-0.601904
# 438
# 0
# action:-0.193911
# 683
# 0
# action:-0.468381
# 518
# 6
# action:-0.091299
# 745
# None
# INSERT INTO test(step,score) VALUES('6','6')
# action:-0.123504
# 725
# 0
# action:-0.336075
# 598
# 0
# action:-0.532473
# 480
# 0
# action:-0.287255
# 627
# None
# INSERT INTO test(step,score) VALUES('4','0')
